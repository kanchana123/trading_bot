# %% [markdown]
# - Read orders csv file
# - get historical data from AngelApi from base_models
# - plot candlestick chart with technical indicators
# - show buy and sell orders on the chart with markers
# - show full run of the backtesting
